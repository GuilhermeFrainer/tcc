# %%
import pandas as pd
import utils
from sktime.utils.plotting import plot_series
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dados/dados_crus.csv", sep=";", decimal=",")
df = df.drop(columns=df.columns.difference(["month", "ipca"]))
df = utils.index_to_datetime(df)
df.head(5)
# Out:
#             ipca
# month
# 2004-01-01  0.76
# 2004-02-01  0.61
# 2004-03-01  0.47
# 2004-04-01  0.37
# 2004-05-01  0.51

# %%
fig, ax = plt.subplots(1, figsize=(10,5))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
ax.plot(df.index, df['ipca'])

# %%
fig.savefig("inflação.png")
